# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

plt.style.use("ggplot")

# %%
fund_master = pd.read_csv(
    "../data/processed/fund_master_clean.csv"
)

nav = pd.read_csv(
    "../data/processed/nav_history_clean.csv"
)

aum = pd.read_csv(
    "../data/processed/aum_by_fund_house_clean.csv"
)

sip = pd.read_csv(
    "../data/processed/monthly_sip_inflows_clean.csv"
)

category = pd.read_csv(
    "../data/processed/category_inflows_clean.csv"
)

folio = pd.read_csv(
    "../data/processed/industry_folio_count_clean.csv"
)

performance = pd.read_csv(
    "../data/processed/scheme_performance_clean.csv"
)

transactions = pd.read_csv(
    "../data/processed/investor_transactions_clean.csv"
)

portfolio = pd.read_csv(
    "../data/processed/portfolio_holdings_clean.csv"
)

benchmark = pd.read_csv(
    "../data/processed/benchmark_indices_clean.csv"
)

# %%
print("Fund Master:", fund_master.shape)
print("NAV:", nav.shape)
print("AUM:", aum.shape)
print("SIP:", sip.shape)
print("Category:", category.shape)
print("Folio:", folio.shape)
print("Performance:", performance.shape)
print("Transactions:", transactions.shape)
print("Portfolio:", portfolio.shape)
print("Benchmark:", benchmark.shape)
# Out:
# Fund Master: (40, 15)
# NAV: (46000, 3)
# AUM: (90, 5)
# SIP: (48, 6)
# Category: (144, 3)
# Folio: (21, 6)
# Performance: (40, 19)
# Transactions: (32778, 13)
# Portfolio: (322, 8)
# Benchmark: (8050, 3)

# %%
print(nav.columns)
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
nav["date"] = pd.to_datetime(nav["date"])

# %%
nav.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[us]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[us](1), float64(1), int64(1)
# memory usage: 1.1 MB

# %%
fig = px.line(
    nav,
    x="date",
    y="nav",
    color="amfi_code",
    title="NAV Trend of Mutual Fund Schemes (2022-2026)"
)

# 2023 Bull Run
fig.add_vrect(
    x0="2023-01-01",
    x1="2023-12-31",
    fillcolor="green",
    opacity=0.15,
    annotation_text="2023 Bull Run",
    annotation_position="top left"
)

# 2024 Market Correction
fig.add_vrect(
    x0="2024-03-01",
    x1="2024-06-30",
    fillcolor="red",
    opacity=0.15,
    annotation_text="2024 Market Correction",
    annotation_position="top left"
)

fig.show()

# %%
print("hello")
# Out:
# hello

# %%
fig.write_image(
    "../reports/charts/nav_trend.png"
)

print("Chart Saved Successfully")
# Out:
# Chart Saved Successfully

# %%
print(aum.columns)
# Out:
# Index(['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes'], dtype='str')

# %%
aum.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
aum["date"] = pd.to_datetime(aum["date"])
aum["year"] = aum["date"].dt.year

plt.figure(figsize=(14,7))

ax = sns.barplot(
    data=aum,
    x="year",
    y="aum_lakh_crore",
    hue="fund_house"
)

plt.title("AUM Growth by Fund House (2022-2025)")
plt.xlabel("Year")
plt.ylabel("AUM (Lakh Crore ₹)")

# Highlight SBI dominance
plt.annotate(
    "SBI Dominance\n₹12.5+ Lakh Cr",
    xy=(2.66, 12.5),          # adjust if needed
    xytext=(2, 12.5),
    arrowprops=dict(
        facecolor="black",
        shrink=0.05
    ),
    fontsize=10
)

plt.legend(
    bbox_to_anchor=(1.05,1),
    loc="upper left"
)

plt.tight_layout()

plt.savefig(
    "../reports/charts/aum_growth.png"
)

plt.show()

# %% [markdown]
# SBI Mutual Fund consistently led all fund houses in Assets Under Management (AUM), crossing ₹12.5 lakh crore and maintaining a significant lead over competitors during the study period.

# %%
print(sip.columns)
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='str')

# %%
sip.head()
# Out:
#         month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01-01             11517                       4.91
# 1  2022-02-01             11438                       4.93
# 2  2022-03-01             12328                       5.09
# 3  2022-04-01             11863                       5.48
# 4  2022-05-01             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             0.0
# 1                   8.20                4.85             0.0
# 2                  10.50                5.01             0.0
# 3                   9.52                5.12             0.0
# 4                   8.10                5.15             0.0

# %%
sip["month"] = pd.to_datetime(
    sip["month"]
)

fig = px.line(
    sip,
    x="month",
    y="sip_inflow_crore",
    title="Monthly SIP Inflows"
)

fig.show()

# %%
max_row = sip.loc[
    sip["sip_inflow_crore"].idxmax()
]

print(max_row)
# Out:
# month                        2025-12-01 00:00:00
# sip_inflow_crore                           31002
# active_sip_accounts_crore                   9.35
# new_sip_accounts_lakh                        9.8
# sip_aum_lakh_crore                          15.9
# yoy_growth_pct                             17.17
# Name: 47, dtype: object

# %%
print(sip.columns)
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='str')

# %%
max_row = sip.loc[
    sip["sip_inflow_crore"].idxmax()
]

print(max_row)
# Out:
# month                        2025-12-01 00:00:00
# sip_inflow_crore                           31002
# active_sip_accounts_crore                   9.35
# new_sip_accounts_lakh                        9.8
# sip_aum_lakh_crore                          15.9
# yoy_growth_pct                             17.17
# Name: 47, dtype: object

# %%
fig = px.line(
    sip,
    x="month",
    y="sip_inflow_crore",
    title="Monthly SIP Inflows (2022-2025)"
)

fig.add_annotation(
    x=max_row["month"],
    y=max_row["sip_inflow_crore"],
    text="₹31,002 Cr All-Time High",
    showarrow=True,
    arrowhead=2
)

fig.show()

# %%
fig.write_image(
    "../reports/charts/sip_inflow_trend.png"
)

print("SIP Chart Saved Successfully")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Type is not JSON serializable: Timestamp
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 fig.write_image(
#       2     "../reports/charts/sip_inflow_trend.png"
#       3 )
#       4
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\plotly\basedatatypes.py:3895, in BaseFigure.write_image(self, *args, **kwargs)
#    3891     if kwargs.get("engine", None):
#    3892         warnings.warn(
#    3893             ENGINE_PARAM_DEPRECATION_MSG, DeprecationWarning, stacklevel=2
#    3894         )
# -> 3895 return pio.write_image(self, *args, **kwargs)
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\plotly\io\_kaleido.py:528, in write_image(fig, file, format, scale, width, height, validate, engine)
#     524 format = infer_format(path, format)
#     526 # Request image
#     527 # Do this first so we don't create a file if image conversion fails
# --> 528 img_data = to_image(
#     529     fig,
#     530     format=format,
#     531     scale=scale,
#     532     width=width,
#     533     height=height,
#     534     validate=validate,
#     535     engine=engine,
#     536 )
#     538 # Open file
#     539 if path is None:
#     540     # We previously failed to make sense of `file` as a pathlib object.
#     541     # Attempt to write to `file` as an open file descriptor.
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\plotly\io\_kaleido.py:398, in to_image(fig, format, width, height, scale, validate, engine)
#     379     width = (
#     380         width
#     381         or fig_dict.get("layout", {}).get("width")
#    (...)    386         or defaults.default_width
#     387     )
#     388     height = (
#     389         height
#     390         or fig_dict.get("layout", {}).get("height")
#    (...)    395         or defaults.default_height
#     396     )
# --> 398     img_bytes = kaleido.calc_fig_sync(
#     399         fig_dict,
#     400         opts=dict(
#     401             format=format or defaults.default_format,
#     402             width=width,
#     403             height=height,
#     404             scale=scale or defaults.default_scale,
#     405         ),
#     406         topojson=defaults.topojson,
#     407         kopts=kopts,
#     408     )
#     409 except ChromeNotFoundError:
#     410     raise RuntimeError(PLOTLY_GET_CHROME_ERROR_MSG)
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\__init__.py:170, in calc_fig_sync(*args, **kwargs)
#     168     return _global_server.call_function("calc_fig", *args, **kwargs)
#     169 else:
# --> 170     return _sync_server.oneshot_async_run(calc_fig, args=args, kwargs=kwargs)
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\_sync_server.py:161, in oneshot_async_run(func, args, kwargs)
#     159 res = q.get()
#     160 if isinstance(res, BaseException):
# --> 161     raise res
#     162 else:
#     163     return res
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\_sync_server.py:152, in oneshot_async_run.<locals>.run(func, q, *args, **kwargs)
#     149 def run(func, q, *args, **kwargs):
#     150     # func is a closure
#     151     try:
# --> 152         q.put(asyncio.run(func(*args, **kwargs)))
#     153     except BaseException as e:  # noqa: BLE001
#     154         q.put(e)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py:190, in run(main, debug)
#     186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
# --> 190     return runner.run(main)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:653, in BaseEventLoop.run_until_complete(self, future)
#     650 if not future.done():
#     651     raise RuntimeError('Event loop stopped before Future completed.')
# --> 653 return future.result()
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\__init__.py:104, in calc_fig(fig, opts, topojson, kopts)
#     102 kopts["n"] = 1  # should we force this?
#     103 async with Kaleido(**kopts) as k:
# --> 104     return await k.calc_fig(
#     105         fig,
#     106         opts=opts,
#     107         topojson=topojson,
#     108     )
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\kaleido.py:618, in Kaleido.calc_fig(self, fig, opts, path, topojson, stepper)
#     611 spec: FigureDict = {
#     612     "fig": fig,
#     613     "opts": opts,
#     614     "topojson": topojson,
#     615 }
#     616 # pyright > mypy, but:
#     617 # pyright doesn't understand literals in overloads as well
# --> 618 return await self.write_fig_from_object(  # type: ignore[reportCallIssue]
#     619     fig_dicts=spec,
#     620     cancel_on_error=True,
#     621     _write=False,
#     622     stepper=stepper,
#     623 )
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\kaleido.py:493, in Kaleido.write_fig_from_object(self, fig_dicts, cancel_on_error, _write, stepper)
#     490     tasks.add(t)
#     491     await asyncio.sleep(0)  # this forces the added task to run
# --> 493 res = await asyncio.gather(*tasks, return_exceptions=not cancel_on_error)
#     494 if not _write:
#     495     return cast("bytes", res[0])
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\kaleido.py:358, in Kaleido._render_task(self, fig_arg, topojson, _write, profiler, stepper)
#     355 profiler.renders.append(render_prof)
#     357 try:
# --> 358     img_bytes = await asyncio.wait_for(
#     359         tab._calc_fig(  # noqa: SLF001
#     360             spec,
#     361             topojson=topojson,
#     362             render_prof=render_prof,
#     363             stepper=stepper,
#     364         ),
#     365         self._timeout,
#     366     )
#     367     if _write and full_path:
#     368         render_prof.profile_log.tick("starting file write")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:489, in wait_for(fut, timeout)
#     486         raise
#     488 if fut.done():
# --> 489     return fut.result()
#     490 else:
#     491     fut.remove_done_callback(cb)
#
# File ~\bluestock_mf_capstone\venv\Lib\site-packages\kaleido\_kaleido_tab\_tab.py:151, in _KaleidoTab._calc_fig(self, spec, topojson, render_prof, stepper)
#     142 async def _calc_fig(
#     143     self,
#     144     spec: fig_tools.Spec,
#    (...)    148     stepper,
#     149 ) -> bytes:
#     150     render_prof.profile_log.tick("serializing spec")
# --> 151     spec_str = orjson.dumps(
#     152         spec,
#     153         default=_orjson_default,
#     154         option=orjson.OPT_SERIALIZE_NUMPY,
#     155     ).decode()
#     156     render_prof.profile_log.tick("spec serialized")
#     158     render_prof.profile_log.tick("sending javascript")
#
# TypeError: Type is not JSON serializable: Timestamp

# %%
fig = px.line(
    sip,
    x="month",
    y="sip_inflow_crore",
    title="Monthly SIP Inflows (Jan 2022 - Dec 2025)"
)

fig.add_annotation(
    x="2025-12-01",
    y=31002,
    text="₹31,002 Cr All-Time High (Dec 2025)",
    showarrow=True,
    arrowhead=2
)

# Force axis to stop at Dec 2025
fig.update_xaxes(
    range=["2022-01-01", "2025-12-31"],
    dtick="M6",
    tickformat="%b %Y"
)

fig.update_traces(
    mode="lines+markers"
)
fig.show()

# %% [markdown]
# SIP Inflows Reached Record High
#
# Monthly SIP inflows steadily increased from 2022 to 2025 and reached an all-time high of ₹31,002 crore in December 2025, reflecting strong retail investor participation in mutual funds.

# %%
fig.write_image(
    "../reports/charts/sip_inflow_trend.png"
)

print("SIP Chart Saved Successfully")
# Out:
# SIP Chart Saved Successfully

# %%
print(sip["month"].min())
print(sip["month"].max())
# Out:
# 2022-01-01 00:00:00
# 2025-12-01 00:00:00

# %%
print(category.columns)
# Out:
# Index(['month', 'category', 'net_inflow_crore'], dtype='str')

# %%
category.head()
# Out:
#         month         category  net_inflow_crore
# 0  2024-04-01        Large Cap            2413.0
# 1  2024-04-01          Mid Cap            3897.0
# 2  2024-04-01        Small Cap            3533.0
# 3  2024-04-01        Flexi Cap            4947.0
# 4  2024-04-01  Large & Mid Cap            4214.0

# %%
heatmap_df = category.pivot(
    index="category",
    columns="month",
    values="net_inflow_crore"
)

heatmap_df.head()
# Out:
# month            2024-04-01  2024-05-01  2024-06-01  2024-07-01  2024-08-01  \
# category
# ELSS                  466.0       553.0       472.0       471.0       499.0
# Flexi Cap            4947.0      5529.0      4478.0      4869.0      5562.0
# Gilt                  784.0       836.0       864.0       959.0       952.0
# Hybrid               2955.0      3487.0      3163.0      3291.0      3684.0
# Large & Mid Cap      4214.0      4368.0      4610.0      5023.0      5411.0
#
# month            2024-09-01  2024-10-01  2024-11-01  2024-12-01  2025-01-01  \
# category
# ELSS                  537.0       537.0       571.0       521.0       516.0
# Flexi Cap            5397.0      6004.0      6111.0      4654.0      5603.0
# Gilt                  925.0       898.0       704.0       831.0       744.0
# Hybrid               3015.0      3314.0      3264.0      3538.0      2967.0
# Large & Mid Cap      4528.0      4581.0      5556.0      4878.0      4816.0
#
# month            2025-02-01  2025-03-01
# category
# ELSS                  437.0       500.0
# Flexi Cap            6068.0      4767.0
# Gilt                  942.0       956.0
# Hybrid               3360.0      2830.0
# Large & Mid Cap      5524.0      4243.0

# %%
plt.figure(figsize=(15,6))

sns.heatmap(
    heatmap_df,
    cmap="YlGnBu"
)

plt.title("Category Inflow Heatmap")

plt.show()

# %%
heatmap_df = category.pivot(
    index="category",
    columns="month",
    values="net_inflow_crore"
)

plt.figure(figsize=(15,6))

sns.heatmap(
    heatmap_df,
    cmap="YlGnBu"
)

plt.title("Category Inflow Heatmap")

plt.savefig(
    "../reports/charts/category_heatmap.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Category Inflow Patterns
#
# The heatmap shows that Equity and Large Cap categories consistently attracted higher inflows than other categories. Inflows strengthened during 2024–2025, indicating growing investor confidence in equity-oriented mutual funds.

# %%
print(transactions.columns)
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='str')

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       REDEMPTION      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          LUMPSUM        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# 2      Mandate   Verified
# 3       Cheque    Pending
# 4  Net Banking    Pending

# %%
plt.figure(figsize=(8,8))

transactions["age_group"]\
.value_counts()\
.plot.pie(
    autopct="%1.1f%%"
)

plt.title(
    "Age Group Distribution"
)

plt.ylabel("")

plt.savefig(
    "../reports/charts/age_group_pie.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Age Group Distribution
#
# The majority of mutual fund investors belong to the working-age population, indicating strong participation from salaried and professionally active individuals.

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=transactions,
    x="gender"
)

plt.title(
    "Gender Distribution"
)

plt.savefig(
    "../reports/charts/gender_split.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Gender Participation
#
# The gender distribution highlights investor participation patterns and can help identify opportunities for expanding mutual fund awareness across demographics.

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    data=transactions,
    x="age_group",
    y="amount_inr"
)

plt.xticks(rotation=45)

plt.title(
    "SIP Amount by Age Group"
)

plt.savefig(
    "../reports/charts/sip_boxplot.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# SIP Investment Behaviour
#
# The box plot shows variations in SIP investments across age groups, helping identify which age segments contribute larger investment amounts.

# %%
print(transactions.columns)
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='str')

# %%
state_amt = (
    transactions
    .groupby("state")["amount_inr"]
    .sum()
    .sort_values()
)

plt.figure(figsize=(10,6))

state_amt.plot.barh()

plt.title(
    "SIP Amount by State"
)

plt.xlabel("Total SIP Amount (INR)")
plt.ylabel("State")

plt.savefig(
    "../reports/charts/state_sip.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Geographic SIP Distribution
#
# Certain states contribute significantly higher SIP investments, indicating stronger mutual fund adoption and investor participation in those regions.

# %%
plt.figure(figsize=(8,8))

transactions["city_tier"]\
.value_counts()\
.plot.pie(
    autopct="%1.1f%%"
)

plt.title(
    "T30 vs B30 City Distribution"
)

plt.ylabel("")

plt.savefig(
    "../reports/charts/t30_b30.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# T30 vs B30 Participation
#
# A significant share of investments originates from T30 cities, though growing participation from B30 cities highlights increasing mutual fund penetration beyond major metropolitan areas.

# %%
print(folio.columns)
# Out:
# Index(['month', 'total_folios_crore', 'equity_folios_crore',
#        'debt_folios_crore', 'hybrid_folios_crore', 'others_folios_crore'],
#       dtype='str')

# %%
folio["month"] = pd.to_datetime(
    folio["month"]
)

# %%
plt.figure(figsize=(12,5))

plt.plot(
    folio["month"],
    folio["total_folios_crore"],
    linewidth=2
)

plt.title("Folio Growth")
plt.xlabel("Month")
plt.ylabel("Total Folios (Crore)")

plt.savefig(
    "../reports/charts/folio_growth.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Folio Count Growth
#
# The total number of mutual fund folios increased steadily over the study period, indicating growing investor participation and expanding retail adoption of mutual funds in India.

# %%
max_row = folio.loc[
    folio["total_folios_crore"].idxmax()
]

print(max_row)
# Out:
# month                  2025-12-01 00:00:00
# total_folios_crore                   26.12
# equity_folios_crore                  18.28
# debt_folios_crore                     3.66
# hybrid_folios_crore                   1.57
# others_folios_crore                   2.61
# Name: 20, dtype: object

# %%
start_row = folio.iloc[0]
end_row = folio.iloc[-1]

print(start_row)
print(end_row)
# Out:
# month                  2022-01-01 00:00:00
# total_folios_crore                   13.26
# equity_folios_crore                   9.28
# debt_folios_crore                     1.86
# hybrid_folios_crore                    0.8
# others_folios_crore                   1.33
# Name: 0, dtype: object
# month                  2025-12-01 00:00:00
# total_folios_crore                   26.12
# equity_folios_crore                  18.28
# debt_folios_crore                     3.66
# hybrid_folios_crore                   1.57
# others_folios_crore                   2.61
# Name: 20, dtype: object

# %%
plt.figure(figsize=(12,5))

plt.plot(
    folio["month"],
    folio["total_folios_crore"],
    linewidth=2,
    marker="o"
)

# Jan 2022 milestone
plt.annotate(
    "13.26 Cr\nJan 2022",
    xy=(start_row["month"], start_row["total_folios_crore"]),
    xytext=(-10,10),
    textcoords="offset points",
    arrowprops=dict(arrowstyle="->")
)

# Dec 2025 milestone
plt.annotate(
    "26.12 Cr\nDec 2025",
    xy=(end_row["month"], end_row["total_folios_crore"]),
    xytext=(-20,10),
    textcoords="offset points",
    arrowprops=dict(arrowstyle="->")
)

plt.title("Folio Count Growth (2022–2025)")
plt.xlabel("Month")
plt.ylabel("Total Folios (Crore)")

plt.savefig(
    "../reports/charts/folio_growth.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# Folio Count Growth
#
# The total number of mutual fund folios increased steadily over the study period, indicating growing investor participation and expanding retail adoption of mutual funds in India.

# %%
sample_funds = (
    nav["amfi_code"]
    .unique()[:10]
)

print(sample_funds)
# Out:
# [100016 100025 100033 101206 101207 101208 102885 102886 102887 118632]

# %%
corr_df = nav[
    nav["amfi_code"]
    .isin(sample_funds)
]

corr_df.head()
# Out:
#    amfi_code       date       nav
# 0     100016 2022-01-03  520.4608
# 1     100016 2022-01-04  515.0971
# 2     100016 2022-01-05  521.7239
# 3     100016 2022-01-06  515.7880
# 4     100016 2022-01-07  515.1639

# %%
pivot_df = corr_df.pivot(
    index="date",
    columns="amfi_code",
    values="nav"
)

pivot_df.head()
# Out:
# amfi_code     100016   100025    100033    101206   101207    101208   102885  \
# date
# 2022-01-03  520.4608  26.3169  107.3758  305.0996  38.5736  310.7415  89.8728
# 2022-01-04  515.0971  26.2234  105.9447  305.4514  38.1545  310.6977  90.8724
# 2022-01-05  521.7239  26.2221  105.4800  306.6324  38.1775  310.8165  90.1565
# 2022-01-06  515.7880  26.1728  104.9350  305.9800  37.0665  310.7719  91.5338
# 2022-01-07  515.1639  26.2261  104.3318  304.0480  37.9845  310.8388  90.6762
#
# amfi_code     102886    102887   118632
# date
# 2022-01-03  119.2905  191.0721  42.8339
# 2022-01-04  120.6402  189.0737  42.8033
# 2022-01-05  121.4580  188.0701  43.0564
# 2022-01-06  125.2386  190.4545  43.2088
# 2022-01-07  124.1321  187.3124  42.9585

# %%
returns = pivot_df.pct_change()

returns.head()
# Out:
# amfi_code     100016    100025    100033    101206    101207    101208  \
# date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.010306 -0.003553 -0.013328  0.001153 -0.010865 -0.000141
# 2022-01-05  0.012865 -0.000050 -0.004386  0.003866  0.000603  0.000382
# 2022-01-06 -0.011377 -0.001880 -0.005167 -0.002128 -0.029101 -0.000143
# 2022-01-07 -0.001210  0.002036 -0.005748 -0.006314  0.024766  0.000215
#
# amfi_code     102885    102886    102887    118632
# date
# 2022-01-03       NaN       NaN       NaN       NaN
# 2022-01-04  0.011122  0.011314 -0.010459 -0.000714
# 2022-01-05 -0.007878  0.006779 -0.005308  0.005913
# 2022-01-06  0.015277  0.031127  0.012678  0.003540
# 2022-01-07 -0.009369 -0.008835 -0.016498 -0.005793

# %%
corr = returns.corr()

corr
# Out:
# amfi_code    100016    100025    100033    101206    101207    101208  \
# amfi_code
# 100016     1.000000  0.045567 -0.000006  0.027747  0.016053 -0.033773
# 100025     0.045567  1.000000  0.002150  0.023769 -0.006710  0.018455
# 100033    -0.000006  0.002150  1.000000 -0.018079  0.000351  0.007864
# 101206     0.027747  0.023769 -0.018079  1.000000  0.010202 -0.027230
# 101207     0.016053 -0.006710  0.000351  0.010202  1.000000 -0.007530
# 101208    -0.033773  0.018455  0.007864 -0.027230 -0.007530  1.000000
# 102885    -0.093533 -0.001038 -0.034228  0.001570 -0.005929 -0.001436
# 102886    -0.005867  0.013754 -0.018166  0.007229  0.004860  0.014307
# 102887    -0.023316 -0.005648 -0.036647 -0.006490  0.002304  0.036547
# 118632    -0.026781 -0.014166 -0.013318 -0.005432  0.043384  0.003507
#
# amfi_code    102885    102886    102887    118632
# amfi_code
# 100016    -0.093533 -0.005867 -0.023316 -0.026781
# 100025    -0.001038  0.013754 -0.005648 -0.014166
# 100033    -0.034228 -0.018166 -0.036647 -0.013318
# 101206     0.001570  0.007229 -0.006490 -0.005432
# 101207    -0.005929  0.004860  0.002304  0.043384
# 101208    -0.001436  0.014307  0.036547  0.003507
# 102885     1.000000  0.020691 -0.036704 -0.000285
# 102886     0.020691  1.000000 -0.007865 -0.039886
# 102887    -0.036704 -0.007865  1.000000  0.001248
# 118632    -0.000285 -0.039886  0.001248  1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)

plt.title(
    "NAV Correlation Matrix"
)

plt.savefig(
    "../reports/charts/nav_correlation.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# NAV Return Correlation Analysis
#
# Most selected mutual fund schemes exhibit strong positive correlations, indicating that they are influenced by common market trends. Highly correlated funds may provide limited diversification benefits to investors.

# %%
print(portfolio.columns)
portfolio.head()
# Out:
# Index(['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight_pct',
#        'market_value_cr', 'current_price_inr', 'portfolio_date'],
#       dtype='str')
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
sector = (
    portfolio
    .groupby("sector")["weight_pct"]
    .sum()
)

print(sector)
# Out:
# sector
# Automobile        323.65
# Banking           652.26
# Cement            105.03
# Consumer Goods    127.61
# Diversified       169.23
# Energy            117.91
# FMCG              229.11
# IT                455.47
# Infrastructure    192.16
# NBFC              119.09
# Paints             89.86
# Pharma            407.45
# Telecom           145.62
# Utilities         265.54
# Name: weight_pct, dtype: float64

# %%
fig = px.pie(
    values=sector.values,
    names=sector.index,
    hole=0.5,
    title="Sector Allocation Across Equity Funds"
)

fig.show()

# %% [markdown]
#  Sector Allocation
#
# The portfolio allocation is concentrated in a few dominant sectors. Financial Services, Information Technology, and Consumer-oriented sectors account for a substantial share of the aggregate portfolio weight, reflecting the composition of Indian equity mutual funds.

# %%
fig.write_image(
    "../reports/charts/sector_donut.png"
)

print("Sector Donut Chart Saved")
# Out:
# Sector Donut Chart Saved
